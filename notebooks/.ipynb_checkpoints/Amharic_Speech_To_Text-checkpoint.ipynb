# %% [markdown]
# ## **Imports**

# %%
# setting path

import sys
sys.path.append('../scripts')
from dataset_loader import load_audio_files, load_transcripts, load_spectrograms_with_transcripts, load_spectrograms_with_transcripts_in_batches
from resize_and_augment import resize_audios_mono, augment_audio, equalize_transcript_dimension
from FeatureExtraction import FeatureExtraction
from transcript_encoder import fit_label_encoder, encode_transcripts, decode_predicted
from models import model_1
sys.path.append('../notebooks')
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\HP\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
import librosa   #for audio processing
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
import warnings
import os
import mlflow
import mlflow.keras
import logging
len(os.listdir('../data/train/wav/'))
# Out:
# 9

# %%
sample_rate = 22050

# %% [markdown]
# ## **Load Audio Files**

# %%
audio_files, maximum_length = load_audio_files('../data/train/wav/', sample_rate, True)
logging.info('loaded audio files')

# %%
print("The longest audio is",maximum_length/sample_rate, 'seconds long')
# Out:
# The longest audio is 9.088027210884354 seconds long

# %% [markdown]
# ## **Load Transcripts**

# %%
transcripts = load_transcripts("../data/train/trsTrain.txt")
logging.info('loaded transcripts')

# %%
maximum_length
# Out:
# 200391

# %% [markdown]
# **Sample audio along with transcript**

# %%
demo_audio = list(audio_files.keys())[0]

# %%
ipd.Audio(audio_files[demo_audio], rate=sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(10, 5))
librosa.display.waveplot(audio_files[demo_audio], sr=sample_rate)

# %%
transcripts[demo_audio]
# Out:
# ' የተለያዩ የ ትግራይ አውራጃ ተወላጆች ገንዘባቸው ን አዋጥ ተው የ ልማት ተቋማትን እንዲ መሰርቱ ትልማ አይ ፈቅድ ም'

# %% [markdown]
# ## **Resize Audios For Mono Channel**

# %%
audio_files = resize_audios_mono(audio_files, maximum_length)
print(audio_files[demo_audio].shape)
# Out:
# (200391,)

# %% [markdown]
# **Sample Padded Audio**

# %%
ipd.Audio(audio_files[demo_audio], rate=sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **Waveplot For Padded Audio**

# %%
plt.figure(figsize=(10, 5))
librosa.display.waveplot(audio_files[demo_audio], sr= sample_rate)

# %% [markdown]
# ## **Augment Audios**

# %%
audio_files = augment_audio(audio_files, sample_rate)

# %% [markdown]
# ## **Extract Features**

# %%
feature_extractor = FeatureExtraction()

# %%
mfcc_features = feature_extractor.extract_features(audio_files, sample_rate)

# %% [markdown]
# **Plot MFCCs**

# %%
fig, ax = plt.subplots()
ax = plt.Axes(fig, [0., 0., 1., 1.])
ax.set_axis_off()
fig.add_axes(ax)
mfccs = mfcc_features[demo_audio]
print(mfccs.shape)
librosa.display.specshow(mfccs, sr=sample_rate, x_axis='time')
# Out:
# (20, 392)

# %% [markdown]
# **Plot Mel Spectrogram**

# %%
X = librosa.stft(audio_files[demo_audio])
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sample_rate, x_axis='time', y_axis='hz')
plt.colorbar()

# %% [markdown]
# **Save MFCC Spectrogram Images**

# %%
feature_extractor.save_mfcc_spectrograms(mfcc_features, sample_rate, '../data/train/mfcc_spectros/')
# Out:
# 0

# %%
ipd.Image(filename=f'../data/train/mfcc_spectros/{demo_audio}.png')

# %% [markdown]
# **Fit Label Encoder with the Characters in the Transcripts**

# %%
char_encoder = fit_label_encoder(transcripts)

# %% [markdown]
# **Encode the Characters in the Transcripts**

# %%
transcripts_encoded = encode_transcripts(transcripts, char_encoder)

# %% [markdown]
# **Equalize transcript length by padding with spaces**

# %%
enc_aug_transcripts = equalize_transcript_dimension(transcripts_encoded, 20)
# Out:
# maximum number of characters in a transcript: 164

# %% [markdown]
# ## **Prepare Training Set**

# %%
# X_train, y_train = load_spectrograms_with_transcripts(mfcc_features, 
#                                                       enc_aug_transcripts,
#                                                       '../data/train/mfcc_spectros/')
# X_train.shape, len(y_train)

# %%
# X_train, y_train = load_spectrograms_with_transcripts_in_batches(mfcc_features, 
#                                                       enc_aug_transcripts, 4, 0,
#                                                       '../data/train/mfcc_spectros/')
# X_train.shape, y_train.shape

# %% [markdown]
# ## **Deep Learning Model**

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.2.0'

# %%
model = model_1(char_encoder)
model.summary()
# Out:
# Model: "ocr_model_v1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image (InputLayer)              [(None, 400, 600, 4) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 400, 600, 32) 1184        image[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 200, 300, 32) 0           Conv1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 200, 9600)    0           pool1[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 200, 64)      614464      reshape[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 200, 64)      0           dense1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 200, 256)     197632      dropout[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 200, 128)     164352      bidirectional[0][0]
# __________________________________________________________________________________________________
# label (InputLayer)              [(None, None)]       0
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 200, 223)     28767       bidirectional_1[0][0]
# __________________________________________________________________________________________________
# ctc_loss (CTCLayer)             (None, 200, 223)     0           label[0][0]
# ==================================================================================================
# Total params: 1,006,399
# Trainable params: 1,006,399
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## **Train Model**

# %% [markdown]
# This module loads data_batch_size spectrograms at a time and trains the model for the given number of epochs and with a given training_batch_size.

# %%
import math

data_batch_size = 4
training_batch_size = 1
number_of_epochs = 10

number_of_batches = math.ceil(len(mfcc_features)/data_batch_size)

for i in range(number_of_epochs):
    for j in range(number_of_batches):
        print(f'Epoch {i+1}: training batch {j}')
        X_train, y_train = load_spectrograms_with_transcripts_in_batches(mfcc_features, 
                                                              enc_aug_transcripts, 4, j,
                                                              '../data/train/mfcc_spectros/')
        history = model.fit([X_train, y_train], batch_size = training_batch_size, epochs = 1)
with mlflow.start_run() as run:
    mlflow.log_metric("ctc_loss", history.history['loss'][-1])
# Out:
# Epoch 1: training batch 0
# 4/4 [==============================] - 3s 781ms/step - loss: 68.8235
# Epoch 1: training batch 1
# 4/4 [==============================] - 2s 577ms/step - loss: 65.0986
# Epoch 1: training batch 2
# 1/1 [==============================] - 0s 5ms/step - loss: 78.2216
# Epoch 2: training batch 0
# 4/4 [==============================] - 3s 703ms/step - loss: 68.8409
# Epoch 2: training batch 1
# 4/4 [==============================] - 3s 819ms/step - loss: 64.8730
# Epoch 2: training batch 2
# 1/1 [==============================] - 0s 5ms/step - loss: 75.2500
# Epoch 3: training batch 0
# 4/4 [==============================] - 2s 572ms/step - loss: 68.8210
# Epoch 3: training batch 1
# 4/4 [==============================] - 3s 704ms/step - loss: 64.9121
# Epoch 3: training batch 2
# 1/1 [==============================] - 0s 5ms/step - loss: 72.4347
# Epoch 4: training batch 0
# 4/4 [==============================] - 3s 817ms/step - loss: 69.0114
# Epoch 4: training batch 1
# 4/4 [==============================] - 3s 851ms/step - loss: 64.9865
# Epoch 4: training batch 2
# 1/1 [==============================] - 0s 5ms/step - loss: 70.2376
# Epoch 5: training batch 0
# 4/4 [==============================] - 3s 816ms/step - loss: 68.9537
# Epoch 5: training batch 1
# 4/4 [==============================] - 3s 808ms/step - loss: 65.0588
# Epoch 5: training batch 2
# 1/1 [==============================] - 0s 5ms/step - loss: 68.7960
# Epoch 6: training batch 0
# 4/4 [==============================] - 2s 453ms/step - loss: 68.9953
# Epoch 6: training batch 1
# 4/4 [==============================] - 2s 392ms/step - loss: 64.8257
# Epoch 6: training batch 2
# 1/1 [==============================] - 0s 2ms/step - loss: 67.7017
# Epoch 7: training batch 0
# 4/4 [==============================] - 1s 318ms/step - loss: 68.9483
# Epoch 7: training batch 1
# 4/4 [==============================] - 1s 326ms/step - loss: 64.9774
# Epoch 7: training batch 2
# 1/1 [==============================] - 0s 0s/step - loss: 66.6966
# Epoch 8: training batch 0
# 4/4 [==============================] - 3s 646ms/step - loss: 69.0187
# Epoch 8: training batch 1
# 4/4 [==============================] - 3s 630ms/step - loss: 64.8605
# Epoch 8: training batch 2
# 1/1 [==============================] - 0s 12ms/step - loss: 66.1839
# Epoch 9: training batch 0
# 4/4 [==============================] - 2s 394ms/step - loss: 68.9440
# Epoch 9: training batch 1
# 4/4 [==============================] - 1s 329ms/step - loss: 64.7621
# Epoch 9: training batch 2
# 1/1 [==============================] - 0s 0s/step - loss: 66.1645
# Epoch 10: training batch 0
# 4/4 [==============================] - 1s 351ms/step - loss: 68.9023
# Epoch 10: training batch 1
# 4/4 [==============================] - 1s 349ms/step - loss: 64.8046
# Epoch 10: training batch 2
# 1/1 [==============================] - 0s 5ms/step - loss: 66.1413

# %%
predicted = model.predict([X_train,y_train])
predicted_trans = decode_predicted(predicted, char_encoder)
real_trans = [''.join(char_encoder.inverse_transform(y)) for y in y_train]
print("pridicted:",predicted_trans[0])
print("actual:",real_trans[0])
# Out:
# pridicted:
# actual:  አንድ የመንግስት መላክ ተኛ እ

# %%
import math
math.ceil(9/2)
# Out:
# 5
