# %%
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile #for audio processing
import os
import pickle
import pandas as pd
import librosa   #for audio processing
import librosa.display

# %%
train_path = "../data/train/"
test_path = "../data/test/"

# %%
train_audio_folder  = train_path + "/wav/"
train_script_file = train_path + "trsTrain.txt"

# %%
def extract_transcription_and_labels(file_path):
    transcriptions  = []
    with open(file_path) as f:
        line = f.readline()
        while (line):
            transcriptions.append(line)
            line = f.readline()
    
    labels = []
    label_trans_dict = dict()
    for trans in transcriptions:
        text = trans.replace("<s>", "").replace("</s>", "")
        text = text.replace("</s>", "")
        text = text.strip()

        label = text.split()[-1]

        try:
            label = label.replace("(", "")
            label = label.replace(")", "")  
        except:
            pass

        translation = text.split()[:-1]
        translation = ' '.join(translation)

        label_trans_dict[label] = translation

    return label_trans_dict

# %%
def get_all_wav_paths(folder_path):
    return os.listdir(folder_path)

# %%
def extract_audio(path, max_lenght=10000, sr=8000):
    
    wav_dict = dict()
    wav_paths = get_all_wav_paths(path)
    for path in wav_paths:
        if len(list(wav_dict.keys())) >= max_lenght:
            break
        wav, sample_rate = librosa.load(train_audio_folder+path, sr=8000)
        dur = float(len(wav)/sample_rate)
        channel = len(wav.shape)
        label = path.split(".")[0]
        wav_dict[label] = (wav, dur, channel, sample_rate)
        
    return wav_dict

# %%
def create_meta_data(transcripton_obj, audo_obj):
    translations = []
    durations = []
    labels = []
    channels = []
    srs = []
    for k in audo_obj.keys():
        trans = transcripton_obj[k]
        label = k

        duration = audo_obj[k][1]
        channel = audo_obj[k][2]
        sr = audo_obj[k][3]

        translations.append(trans)
        durations.append(duration)
        labels.append(label)
        channels.append(channel)
        srs.append(sr)

        m_df = pd.DataFrame()
        m_df["translation"] = translations
        m_df["label"] = labels
        m_df["channel"] = channels
        m_df["sample_rate"] = srs
        m_df["duration"] = durations

    return m_df

# %%
def read_obj(path):
    with open(path, "rb") as f:
        return pickle.load(f)
    
def write_obj(path, obj):
    with open(path, "wb") as f:
        pickle.dump(obj, f)

# %%
def read_csv(csv_path, missing_values=[]):
    try:
        df = pd.read_csv(csv_path, na_values=missing_values)
        print("file read as csv")
        return df
    except FileNotFoundError:
        print("file not found")
def save_csv(df, csv_path):
    try:
        df.to_csv(csv_path, index=False)
        print('File Successfully Saved.!!!')

    except Exception:
        print("Save failed...")

    return df

# %%
translation_obj = extract_transcription_and_labels(train_script_file)
audio_dict = extract_audio(train_audio_folder, 50)
# Out:
# Exception ignored in: <function Wave_write.__del__ at 0x1a1c2344d0>
# Traceback (most recent call last):
#   File "/Users/daniel/opt/anaconda3/lib/python3.7/wave.py", line 327, in __del__
#     self.close()
#   File "/Users/daniel/opt/anaconda3/lib/python3.7/wave.py", line 445, in close
#     self._ensure_header_written(0)
#   File "/Users/daniel/opt/anaconda3/lib/python3.7/wave.py", line 465, in _ensure_header_written
#     raise Error('sample width not specified')
# wave.Error: sample width not specified

# %%
write_obj("audio_dict.pkl", audio_dict)
write_obj("translation_dict.pkl", translation_obj)

# %%
translation_obj = read_obj("./translation_dict.pkl")
audio_obj = read_obj("./audio_dict.pkl")
meta_data = create_meta_data(translation_obj, audio_obj)

# %%
meta_data
# Out:
#                                           translation              label  \
# 0   የተለያዩ የ ትግራይ አውራጃ ተወላጆች ገንዘባቸው ን አዋጥ ተው የ ልማት ...  tr_10000_tr097082
# 1              የ ጠመንጃ ተኩስ ተከፈተ ና አራት የኤርትራ ወታደሮች ተገደሉ  tr_10001_tr097083
# 2                    ላነሷቸው ጥያቄዎች የ ሰጡት ን መልስ አቅርበ ነዋል  tr_10002_tr097084
# 3          እ ብዱ አስፋልቱ ላይ የ ኰለኰ ለ ው ድንጋይ መኪና አላ ሳልፍ አለ  tr_10003_tr097085
# 4             ጠጁ ን ኰ መኰ መ ኰ መኰ መ ና ሚስቱ ን ሲ ያሰቃ ያት አደረ  tr_10004_tr097086
# 5                      ድንቹ በ ደንብ ስለተኰተኰተ በ ጥሩ ሁኔታ ኰረተ  tr_10005_tr097087
# 6            በ ድህነቱ ላይ ይህ ክፉ በሽታ ስለ ያዘው ሰውነቱ በጣም ኰ ሰሰ  tr_10006_tr097088
# 7                በሩን እንዲ ህ በ ሀይል አታንኳኲ ብዬ አልነበረ ም እንዴ  tr_10007_tr097089
# 8                             በለጠ ች የ በየነ የ በኩር ልጅ ነች  tr_10008_tr097090
# 9                የ ቆላ ቁስል ና ቁርጥ ማት በጣም አሰቃቂ በሽታዎች ናቸው  tr_10009_tr097091
# 10  ያ ኮምፒ ተር ለ ተጠቃሚው በ ትክክል የሚ ፈለገው ን ነገር እንዲ ያሟላ ...    tr_1000_tr11001
# 11               ባድመ ላይ ያለቀው የኤርትራ ወታደር ስፍር ቁጥር የ ለውም  tr_10010_tr097092
# 12      እንዲያ መሬት አይ ን ካ ኝ ይል የነበረ ሰው በ ድንገት ቆረቆዘ አይደል  tr_10011_tr097093
# 13                              አንበሳው ስጋ ስላ የ አጉረመረ መ  tr_10012_tr097094
# 14                   ሸክላ ሰሪዋ አ ለሚ ቱ በ ጉልቻ ስራ የታወቀች ነች  tr_10013_tr097095
# 15                        የተፈራ አተር ቀድሞ ስለ ተዘራ ተ ሎ ጐመራ  tr_10014_tr097096
# 16  ባልቻ ጐበዝ ተማሪ ስለሆነ ተሸላሚ እንዲሆን የ ትምህርት ማህበረሰብ በ አ...  tr_10015_tr097097
# 17    በ ና ዝሪ ት ከተማ ውስጥ ከሚገኙ ት ቤቶች ሁሉ ጉል ሁ የ ኡመር ቤት ነው  tr_10016_tr097098
# 18                               ጐስቋላ ው ዳም ጤ ሎተሪ ደረሰው  tr_10017_tr097099
# 19                                     ከበደ ፈረሱ ን ለ ጐመ  tr_10018_tr097100
# 20   ትንሽ ልጅ እንጀራ በ ዶሮ ወጥ ከ በላ በኋላ አፉ ን በ ደም ብ ተጉ መጠመጠ  tr_10019_tr097101
# 21  ስዊድን ከ ኢትዮጵያ ጋር ያላትን ግንኙነት አስመልክቶ አዲስ የ ትብብር ስ...    tr_1001_tr11002
# 22                    ገንፎ ብዙ ጊዜ የሚ በላው በ ጐድጓዳ ሳ ህን ነው  tr_10020_tr097102
# 23                   አበራሽ የ ሰፈሩ ነገር ቆስቋሽ መሆኗ የ ታወቀ ነው  tr_10021_tr097103
# 49  በ አሁኑ ሰአት የቤተ ክርስቲያን ሊቃውንት እንዴት እንደ ተ ና ቁና እንደ...  tr_10045_tr098007
#
#     channel  sample_rate  duration
# 0         1         8000     9.088
# 1         1         8000     5.632
# 2         1         8000     6.144
# 3         1         8000     5.760
# 4         1         8000     5.376
# 5         1         8000     6.656
# 6         1         8000     6.528
# 7         1         8000     5.504
# 8         1         8000     4.480
# 9         1         8000     4.864
# 10        1         8000     7.552
# 11        1         8000     5.504
# 12        1         8000     6.016
# 13        1         8000     3.328
# 14        1         8000     5.504
# 15        1         8000     4.864
# 16        1         8000     7.680
# 17        1         8000     6.912
# 18        1         8000     3.840
# 19        1         8000     3.200
# 20        1         8000     6.528
# 21        1         8000     9.344
# 22        1         8000     4.608
# 23        1         8000     5.120
# 24        1         8000     3.584
# 25        1         8000     3.584
# 26        1         8000     3.328
# 27        1         8000     4.992
# 28        1         8000     5.632
# 29        1         8000     4.352
# 30        1         8000     4.608
# 31        1         8000     3.328
# 32        1         8000    11.904
# 33        1         8000     4.608
# 34        1         8000     7.808
# 35        1         8000     4.736
# 36        1         8000     5.248
# 37        1         8000     5.760
# 38        1         8000     3.584
# 39        1         8000     3.328
# 40        1         8000     7.168
# 41        1         8000     3.200
# 42        1         8000     5.504
# 43        1         8000     4.736
# 44        1         8000     3.712
# 45        1         8000     4.096
# 46        1         8000     3.456
# 47        1         8000     5.504
# 48        1         8000     2.816
# 49        1         8000     6.272

# %%
save_csv(meta_data, "meta_data.csv")
# Out:
# File Successfully Saved.!!!
#                                           translation              label  \
# 0   የተለያዩ የ ትግራይ አውራጃ ተወላጆች ገንዘባቸው ን አዋጥ ተው የ ልማት ...  tr_10000_tr097082
# 1              የ ጠመንጃ ተኩስ ተከፈተ ና አራት የኤርትራ ወታደሮች ተገደሉ  tr_10001_tr097083
# 2                    ላነሷቸው ጥያቄዎች የ ሰጡት ን መልስ አቅርበ ነዋል  tr_10002_tr097084
# 3          እ ብዱ አስፋልቱ ላይ የ ኰለኰ ለ ው ድንጋይ መኪና አላ ሳልፍ አለ  tr_10003_tr097085
# 4             ጠጁ ን ኰ መኰ መ ኰ መኰ መ ና ሚስቱ ን ሲ ያሰቃ ያት አደረ  tr_10004_tr097086
# 5                      ድንቹ በ ደንብ ስለተኰተኰተ በ ጥሩ ሁኔታ ኰረተ  tr_10005_tr097087
# 6            በ ድህነቱ ላይ ይህ ክፉ በሽታ ስለ ያዘው ሰውነቱ በጣም ኰ ሰሰ  tr_10006_tr097088
# 7                በሩን እንዲ ህ በ ሀይል አታንኳኲ ብዬ አልነበረ ም እንዴ  tr_10007_tr097089
# 8                             በለጠ ች የ በየነ የ በኩር ልጅ ነች  tr_10008_tr097090
# 9                የ ቆላ ቁስል ና ቁርጥ ማት በጣም አሰቃቂ በሽታዎች ናቸው  tr_10009_tr097091
# 10  ያ ኮምፒ ተር ለ ተጠቃሚው በ ትክክል የሚ ፈለገው ን ነገር እንዲ ያሟላ ...    tr_1000_tr11001
# 11               ባድመ ላይ ያለቀው የኤርትራ ወታደር ስፍር ቁጥር የ ለውም  tr_10010_tr097092
# 37                    መጋቢ ብሉይ ተክለ ማሪያም የተወለዱ ት ዳ ጔ ነው  tr_10034_tr097116
# 38                                 አሊ በ ረሀብ ኩ ርምት ብሏል  tr_10035_tr097117
# 39                       የ ሰርጉ ወጥ ኩ ችም ተደርጐ ነው የ ተሰራው  tr_10036_tr097118
# 40         መ ምሩ እንዳስ ተማሩት ከሆነ ህጻናቶች ም ንም ኩነኔ የ ለ ባቸውም  tr_10037_tr097119
# 41                                  ስ ትመለ ሺ በሩን አንኳ ኲ  tr_10038_tr097120
# 42  በ መጀመሪያ ደረጃ ወራሪ ሆኖ የ ኢትዮጵያ ግዛት ን መያዙ ን አምኖ ለ መ...  tr_10039_tr098001
# 43                            መለፍለፍ ራሱ ዲሞክራሲያዊ መብት ነው    tr_1003_tr11004
# 44                           መለስ ና ኢሳያስ ማስጠንቀቂያ ደረሳቸው  tr_10040_tr098002
# 45                     የኤርትራ ባንዲራ ይውረድ ተብሎ ኤምባሲ ተደበደበ  tr_10041_tr098003
# 46             ኢትዮጵያ ን መብት እንደሌላ ት አድርገው ለማቅረብ ሞክረ ዋል  tr_10042_tr098004
# 47  የ ጋና ው ፕሬዚዳንት ኢትዮጵያ ና ኤርትራ የ ድንበር ው ዝግባ ቸውን በ ...  tr_10043_tr098005
# 48                           እሳት አደጋዎች በተ ጠንቀቅ ላይ ናቸው  tr_10044_tr098006
# 49  በ አሁኑ ሰአት የቤተ ክርስቲያን ሊቃውንት እንዴት እንደ ተ ና ቁና እንደ...  tr_10045_tr098007
#
#     channel  sample_rate  duration
# 0         1         8000     9.088
# 1         1         8000     5.632
# 2         1         8000     6.144
# 3         1         8000     5.760
# 4         1         8000     5.376
# 5         1         8000     6.656
# 6         1         8000     6.528
# 7         1         8000     5.504
# 8         1         8000     4.480
# 9         1         8000     4.864
# 10        1         8000     7.552
# 11        1         8000     5.504
# 12        1         8000     6.016
# 13        1         8000     3.328
# 14        1         8000     5.504
# 15        1         8000     4.864
# 16        1         8000     7.680
# 17        1         8000     6.912
# 18        1         8000     3.840
# 19        1         8000     3.200
# 20        1         8000     6.528
# 21        1         8000     9.344
# 22        1         8000     4.608
# 23        1         8000     5.120
# 24        1         8000     3.584
# 25        1         8000     3.584
# 26        1         8000     3.328
# 27        1         8000     4.992
# 28        1         8000     5.632
# 29        1         8000     4.352
# 30        1         8000     4.608
# 31        1         8000     3.328
# 32        1         8000    11.904
# 33        1         8000     4.608
# 34        1         8000     7.808
# 35        1         8000     4.736
# 36        1         8000     5.248
# 37        1         8000     5.760
# 38        1         8000     3.584
# 39        1         8000     3.328
# 40        1         8000     7.168
# 41        1         8000     3.200
# 42        1         8000     5.504
# 43        1         8000     4.736
# 44        1         8000     3.712
# 45        1         8000     4.096
# 46        1         8000     3.456
# 47        1         8000     5.504
# 48        1         8000     2.816
# 49        1         8000     6.272

# %%
def add_noise(data, noise_factor):
    
    noise = np.random.randn(len(data))
    augmented_data = data + noise_factor * noise
    augmented_data = augmented_data.astype(type(data[0]))
    return augmented_data

def shift_signal(data, sampling_rate, shift_max, shift_direction):
    
    shift = np.random.randint(sampling_rate * shift_max)
    if shift_direction == 'right':
        shift = -shift
        
    elif shift_direction == 'both':
        direction = np.random.randint(0, 2)
        if direction == 1:
            shift = -shift
    augmented_data = np.roll(data, shift)
    # Set to silence for heading/ tailing
    if shift > 0:
        augmented_data[:shift] = 0
    else:
        augmented_data[shift:] = 0
    return augmented_data

def change_picth(data, sampling_rate, pitch_factor):
    return librosa.effects.pitch_shift(data, sampling_rate, pitch_factor)
                                       
def change_speed(data, speed_factor):
    return librosa.effects.time_stretch(data, speed_factor)

# %%
sample_audio_obj = audio_obj['tr_10032_tr097114']
sample_audio = sample_audio_obj[0]
rate = sample_audio_obj[-1]

# %% [markdown]
# ### Data Agumentation, adding noise

# %%
plt.figure(figsize=(12, 5))
librosa.display.waveplot(sample_audio, sr=rate)
plt.title("original", fontsize=16)
plt.show()
display(ipd.Audio(sample_audio, rate=rate))

noise_1 = add_noise(sample_audio, 0.01)

plt.figure(figsize=(12, 5))
librosa.display.waveplot(noise_1, sr=rate)
plt.title("noise", fontsize=16)
plt.show()
ipd.Audio(noise_1, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Shiffiting to left and right

# %%
plt.figure(figsize=(12, 5))
librosa.display.waveplot(sample_audio, sr=rate)
plt.title("original", fontsize=16)
plt.show()
display(ipd.Audio(sample_audio, rate=rate))

right_shift = shift_signal(sample_audio, rate, 8,  "right")

plt.figure(figsize=(12, 5))
plt.title("right_shiftted", fontsize=16)
librosa.display.waveplot(right_shift, sr=rate)
plt.show()
display(ipd.Audio(right_shift, rate=rate))


left_shift = shift_signal(sample_audio, rate, 4,  "left")
plt.figure(figsize=(12, 5))
plt.title("left_shiftted", fontsize=16)
librosa.display.waveplot(left_shift, sr=rate)
plt.show()
display(ipd.Audio(left_shift, rate=rate))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### pitch

# %%
pitch_shift = change_picth(sample_audio, rate, 10)

plt.figure(figsize=(12, 5))
plt.title("pitched", fontsize=16)
librosa.display.waveplot(pitch_shift, sr=rate)
plt.show()
display(ipd.Audio(pitch_shift, rate=rate))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Speed

# %%
speed_man = change_picth(sample_audio, rate, 10)

plt.figure(figsize=(12, 5))
plt.title("speed effect", fontsize=16)
librosa.display.waveplot(speed_man, sr=rate)
plt.show()
display(ipd.Audio(speed_man, rate=rate))
# Out:
# array([-0.08699796, -0.12772891, -0.11267415, ..., -0.13001657,
#        -0.12626636, -0.13736436], dtype=float32)

# %%
class AudioManipulator():
    def init(self,audio,sr,stere=False):
        self.audio=audio,
        self.sr=sr
        self.stereo=bool(self.audio.shape-1)
    def cut(audio,length,):
        trunc=[]
        if self.stereo:
            trunc.append(audio[0][:length])
            trunc.append(audio[1][:length])
        else:
            trunc=audio[:length]
        self.audio=np.array(trunc)
        return self.audio
    def pitch(self,pitch_factor):
        return librosa.effects.pitch_shift(self.audio, self.sr, n_steps=pitch_factor)
    def shift_to(self, shift_max, shift_direction):
        shift = np.random.randint(self.sr * shift_max)
        if shift_direction == 'right':
            shift = shift
        elif self.shift_direction == 'both':
            direction = np.random.randint(0, 2)
            if direction == 1:
                shift = -shift
        elif self.shift_direction == 'left':
            shift=-shift
        augmented_data = np.roll(self.audio, shift)
        # Set to silence for heading/ tailing
        if shift > 0:
            augmented_data[:shift] = 0
        else:
            augmented_data[shift:] = 0
        self.audio=augmented_data
        return self.audio
    def generate_MFCC(self):
        mfccs = librosa.feature.mfcc(self.audio, self.sr)
        return mfccs
