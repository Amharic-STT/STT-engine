# %%
import librosa   #for audio processing
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile #for audio processing
import os
import pickle
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-af499ccc058f> in <module>
# ----> 1 import librosa   #for audio processing
#       2 import IPython.display as ipd
#       3 import matplotlib.pyplot as plt
#       4 import numpy as np
#       5 from scipy.io import wavfile #for audio processing
#
# ModuleNotFoundError: No module named 'librosa'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !!ln -s ./drive/MyDrive/S2T/data/
# Out:
# []

# %%
train_path = "../data/train/"
test_path = "../data/test/"

# %%
train_audio_folder  = train_path + "/wav/"
train_script_file = train_path + "trsTrain.txt"

# %%
def extract_transcription_and_labels(file_path):
    transcriptions  = []
    with open(file_path) as f:
        line = f.readline()
        while (line):
            transcriptions.append(line)
            line = f.readline()
    
    labels = []
    label_trans_dict = dict()
    for trans in transcriptions:
        text = trans.replace("<s>", "").replace("</s>", "")
        text = text.replace("</s>", "")
        text = text.strip()

        label = text.split()[-1]

        try:
        label = label.replace("(", "")
        label = label.replace(")", "")  
        except:
        pass

        translation = text.split()[:-1]
        translation = ' '.join(translation)

        label_trans_dict[label] = translation

    return label_trans_dict

# %%
def get_all_wav_paths(folder_path):
    return os.listdir(folder_path)

# %%
def extract_audio(path, max_lenght=10000, sr=8000):
    wav_dict = dict()
    wav_paths = get_all_wav_paths(path)
    for path in wav_paths:
        if len(list(wav_dict.keys())) >= max_lenght:
            break
        wav, sample_rate = librosa.load(train_audio_folder+path, sr=8000)
        dur = float(len(wav)/sample_rate)
        channel = len(wav.shape)
        label = path.split(".")[0]
        wav_dict[label] = list((wav[0], dur, channel, sample_rate))
    return wav_dict

# %%
def create_meta_data(transcripton_obj, audo_obj):
    translations = []
    durations = []
    labels = []
    channels = []
    srs = []
    for k in audo_obj.keys():
    trans = transcripton_obj[k]
    label = k

    duration = audo_obj[k][1]
    channel = audo_obj[k][2]
    sr = audo_obj[k][3]

    translations.append(trans)
    durations.append(duration)
    labels.append(label)
    channels.append(channel)
    srs.append(sr)

    m_df = pd.DataFrame()
    m_df["translation"] = translations
    m_df["label"] = labels
    m_df["channel"] = channels
    m_df["sample_rate"] = srs
    m_df["duration"] = durations

    return m_df

# %%
def read_obj(path):
    with open(path, "rb") as f:
        return pickle.load(f)
    
def write_obj(path, obj):
    with open(path, "wb") as f:
        pickle.dump(obj, f)

# %%
def read_csv(csv_path, missing_values=[]):
    try:
        df = pd.read_csv(csv_path, na_values=missing_values)
        print("file read as csv")
        return df
    except FileNotFoundError:
        print("file not found")
def save_csv(df, csv_path):
    try:
        df.to_csv(csv_path, index=False)
        print('File Successfully Saved.!!!')

    except Exception:
        print("Save failed...")

    return df

# %%
translation_obj = extract_transcription_and_labels(train_script_file)
audio_dict = extract_audio(train_audio_folder, 50)

# %%
write_obj("audio_dict.pkl", audio_dict)
write_obj("translation_dict.pkl", translation_obj)

# %%
translation_obj = read_obj("./translation_dict.pkl")
audio_obj = read_obj("./audio_dict.pkl")
meta_data = create_meta_data(translation_obj, audio_obj)

# %%
meta_data
# Out:
#                                           translation  ... duration
# 0   እንደ ስሟ አበባ የ ሆነችው ህጻን የመጀመሪያ ው ም ት ሲ ያርፍ ባት ጸጥ...  ...    6.144
# 1   አገልግሎቱ የ ኢትዮጵያ ቴሌኮሚኒኬሽን ኮርፖሬሽ ን ካለ ው ሀገር አቀፍ ጋ...  ...    8.320
# 2                         ባለቤቶቹ ም ሽር ጉድ ብለው አ ስተናገዱ ት  ...    4.352
# 3   ቢ ያንስ በ የ ሶስት ወሩ የ ተጫዋቾች አካላዊ ና አእምሮአዊ ሁኔታዎች ቴ...  ...    6.528
# 4                                ሌሎቹ ም ያው የምና ያቸው ናቸው  ...    4.352
# 5                     ተጫዋቾች ም እንዲ ሁ በ ኮሚቴዎች ላይ ያማር ራሉ  ...    4.224
# 6   የ ህዝብ ን ጥያቄ ማስተናገድ ግዴታ ስለ ነበረብን ወደ አጂፕ ኢትዮጵያ ዋ...  ...    7.552
# 7   የሚያ ፈሰው ከፍተኛ ገንዘብ በ ተገቢ ተጫዋቾች እንዲያዝ ኒያላ አላማው እ...  ...    8.064
# 8                       ብቻ አንዳንዴ ተመልካቹ እንደ እብድ ያደርገዋል  ...    3.456
# 9   አቶ ፍቅሩ በ ተደረገው ውይይት ና በ ሴቶች ተሳትፎ በ መደሰታቸው በ ሀገ...  ...    7.424
# 10  ሳምንቱ ን ሙሉ ጋዜጣው ሬዲዮው ና ቴሌቭዥኑ ሁሉ የሚያወራ ው ስለ ጨዋታው ነው  ...    5.760
# 11  ከፍተኛው ን ድርሻ የሚ ያበረክቱ ት በርካታ ተወዳዳሪ ዎች የሚያቀርቡ ት ...  ...    5.632
# 12  ይህ ማለት ሀያ ሶስት ጊዜ የተለያዩ የ ስፖርት እንዲሁም የ ሙዚቃ ፌስ ቲ...  ...    7.424
# 13  ደብዳቤው ለ ኢንተርናሽናል አርቢትሮቻችን ለ ረዳት ኢንተርናሽናል አርቢትሮ...  ...    7.296
# 14  ዋናው አበይት አንገብጋቢ ው ነገር ሜዳ ነው ና ክልሉ ሌት ተቀን አስቦ በ...  ...    8.320
# 15   የ ፊታችን ቅዳሜ የ ቦስተን ነዋሪ ኢትዮጵያውያ ን ታላቅ ስብሰባ ያ ካሄዳ ሉ  ...    5.888
# 16                 በ ሀገር ውስጥ ውድድሮች ብቻ ተ ወስነ ን እንቀ ራለን  ...    8.448
# 17  የ ሪቨር ፕሌት ቡድን ከ ሜዳው ውጭ ወደ ኤስቱዱዬንቴ ተ ጉዞ አንድ ለ ዜ...  ...    6.528
# 18        ክለቡ የምን ፈልጋቸው ን ተጫዋቾች በ ሙሉ በ እጃችን አስገብቶ ልናል  ...    5.376
# 19  ከ አንድ ሺ ዘጠኝ መቶ ሰባ እስከ ሰማኒያ ድረስ በ ቡንደስሊጋ ውስጥ አን...  ...    9.728
# 20  እነዚህ ጉዳት የ ደረሰባቸው ኢትዮጵያውያ ን በ ሳር ቤት ሞያሌ መንገድ ከ...  ...    8.320
# 21  ኢትዮጵያዊያ ኑ የ ደቡብ አፍሪካ ፕሮፌሰር ጣልቃ እንዲ ገባ እንዲ ገቡ ተማጸኑ  ...    5.760
# 22  እነዚህ ኢትዮጵያውያ ን ኬንያ ዊያን ና ናይጄሪያ ዎች በ ቱርክ ድንበር ላ...  ...   12.160
# 23          የ ዩኒቨርስቲ ተማሪዎች ትናንት ያወጡ ት መግለጫ የ ሚከተለው ነው  ...    4.864
# 24  በ በየነ ጴጥሮስ የሚ መራው የ ተቃዋሚዎች ቅንጅት ብዛት ያ ላቸው ብሄራዊ...  ...    7.296
# 25  በ ተጨማሪ ም ሰማኒያ አንድ ከ መቶ የሚ ሆነው የ ኢትዮጵያ ህዝብ የ ተሟ...  ...    8.064
# 26                  የ ሉ ሲ ቅሪት አሜሪካ ተወስዶ እንደሚ ጐበኝ ተገለጸ  ...    4.864
# 27               ስለዚህ ም እንደ ገና የ ረሀቡ ን ቁልቁለት ይ ያያ ዘዋል  ...    6.016
# 28         ይሁን እንጂ ኢዴፓ ሰላማዊ ትግሉ ሊ ጠናከር እንደሚ ገባ ያ ም ናል  ...    5.504
# 29  በዚህ ጉዳይ ላይ የ ፕሮጀክቱ አስተባባሪ የሆኑት አቶ ኤልያስ እንዳለ ን ...  ...    8.320
# 30                           ህሊናቸው ንም በመ ን ካቴ ደስተኛ ነኝ  ...    3.328
# 31                የ ኦነግ ጦር አዛዥ በ ስቅላት እንዲ ቀጡ ተፈረደ ባቸው  ...    4.480
# 32  የ ኢትዮጵያ ነጻ ፕሬስ ጋዜጠኞች ማህበር በ ቅርቡ በ ኢትዮጵያ ውስጥ ስም...  ...    8.832
# 33  ኦህዴዱ የ ኦሮሚያ ምክትል ፕሬዚዳንት ኮብል ለ ው ዋሽንግተን ውስጥ ከ ኦ...  ...    7.680
# 34      ኢትዮጵያ በምት ገኝበት ስብሰባ አን ካፈል ም አሉ የ ሶማሊያ ፕሬዚዳንት  ...    5.504
# 35  ስድስት የ አስቸኳይ ጊዜ ፕሮጀክቶች እንዲ ነደፉ ም የ አንድ ነጥብ አምስ...  ...    6.400
# 36                  የ ፕሬዝዳንት ግርማ ልጅ አባቱ ን ተክቶ ሊ ሰራ ነው  ...    3.712
# 37                     ፕሮፖጋንዳ ው በ ሻእቢያ ፋሽ ን ይባላል ዛሬ ም  ...    3.328
# 38   ሀያ አራት ክትትል ደህንነቶች እርስ በርስ ተገማግመው ከስራ ገበታ ቸው ተነሱ  ...    6.272
# 39                              ተ ገንጥላ ም ከ እኛው ጋር ና ት  ...    2.944
# 40  ስለ ስደተኞች መወያየት ግን ነገሩን ያሰፋው ና ከ አጉል አምባጓሮ ውስጥ ...  ...    5.504
# 41         እንደ ገና እንዲያ ንሰራሩ የ ህይወት እስትንፋ ስ ነው የዘራ ባቸው  ...    5.504
# 42  ገና ለ ጀሮ ያል በቁ የ ጓዳ ምስጢሮች ካ ሏቸው ይንገሩ ን ለ ነገሩ እና...  ...    5.760
# 43  አሁን ም የ ኢትዮጵያ ህዝብ ዳር እስከ ዳር ያለ ገደብ ገንዘብ እንዲ ያዋ...  ...    5.120
# 44                የቤተ ክርስቲያኒቱ ን አመራር ና አማን ያኑን እን ጠይቅ  ...    3.968
# 45  በ ሻእቢያ በኩል እንኳ ዛሬ መንግስት ሁነ ን ትናንት ም ሰላሳ አመት ተዋ...  ...    6.784
# 46  ህብረቱ ም ጠንካራ ና ዲሞክራሲያዊ ት ኢትዮጵያ እንደምት መሰረት እምነቱ ...  ...    5.760
# 47  ከ ሶስት ሺ በላይ ኤርትራውያን ከ ሀገር ተባረሩ በውጭ የሚኖሩ ትም ተቃው...  ...    5.504
# 48                  በዚህ ደግሞ አትራፊ ዎች እንጂ ተጐጂዎች አይደለ ንም  ...    3.968
# 49  ይህ ሁኔታ በ ኮንጐ ዴሞክራቲክ ሪፐብሊክ የተፈጠረ ውን ችግር ሊ ያወሳስበ...  ...    7.808
#
# [50 rows x 5 columns]

# %%
save_csv(meta_data, "meta_data.csv")
# Out:
# File Successfully Saved.!!!
#                                           translation  ... duration
# 0   እንደ ስሟ አበባ የ ሆነችው ህጻን የመጀመሪያ ው ም ት ሲ ያርፍ ባት ጸጥ...  ...    6.144
# 1   አገልግሎቱ የ ኢትዮጵያ ቴሌኮሚኒኬሽን ኮርፖሬሽ ን ካለ ው ሀገር አቀፍ ጋ...  ...    8.320
# 2                         ባለቤቶቹ ም ሽር ጉድ ብለው አ ስተናገዱ ት  ...    4.352
# 3   ቢ ያንስ በ የ ሶስት ወሩ የ ተጫዋቾች አካላዊ ና አእምሮአዊ ሁኔታዎች ቴ...  ...    6.528
# 4                                ሌሎቹ ም ያው የምና ያቸው ናቸው  ...    4.352
# 5                     ተጫዋቾች ም እንዲ ሁ በ ኮሚቴዎች ላይ ያማር ራሉ  ...    4.224
# 6   የ ህዝብ ን ጥያቄ ማስተናገድ ግዴታ ስለ ነበረብን ወደ አጂፕ ኢትዮጵያ ዋ...  ...    7.552
# 7   የሚያ ፈሰው ከፍተኛ ገንዘብ በ ተገቢ ተጫዋቾች እንዲያዝ ኒያላ አላማው እ...  ...    8.064
# 8                       ብቻ አንዳንዴ ተመልካቹ እንደ እብድ ያደርገዋል  ...    3.456
# 9   አቶ ፍቅሩ በ ተደረገው ውይይት ና በ ሴቶች ተሳትፎ በ መደሰታቸው በ ሀገ...  ...    7.424
# 10  ሳምንቱ ን ሙሉ ጋዜጣው ሬዲዮው ና ቴሌቭዥኑ ሁሉ የሚያወራ ው ስለ ጨዋታው ነው  ...    5.760
# 11  ከፍተኛው ን ድርሻ የሚ ያበረክቱ ት በርካታ ተወዳዳሪ ዎች የሚያቀርቡ ት ...  ...    5.632
# 12  ይህ ማለት ሀያ ሶስት ጊዜ የተለያዩ የ ስፖርት እንዲሁም የ ሙዚቃ ፌስ ቲ...  ...    7.424
# 13  ደብዳቤው ለ ኢንተርናሽናል አርቢትሮቻችን ለ ረዳት ኢንተርናሽናል አርቢትሮ...  ...    7.296
# 14  ዋናው አበይት አንገብጋቢ ው ነገር ሜዳ ነው ና ክልሉ ሌት ተቀን አስቦ በ...  ...    8.320
# 15   የ ፊታችን ቅዳሜ የ ቦስተን ነዋሪ ኢትዮጵያውያ ን ታላቅ ስብሰባ ያ ካሄዳ ሉ  ...    5.888
# 16                 በ ሀገር ውስጥ ውድድሮች ብቻ ተ ወስነ ን እንቀ ራለን  ...    8.448
# 17  የ ሪቨር ፕሌት ቡድን ከ ሜዳው ውጭ ወደ ኤስቱዱዬንቴ ተ ጉዞ አንድ ለ ዜ...  ...    6.528
# 18        ክለቡ የምን ፈልጋቸው ን ተጫዋቾች በ ሙሉ በ እጃችን አስገብቶ ልናል  ...    5.376
# 19  ከ አንድ ሺ ዘጠኝ መቶ ሰባ እስከ ሰማኒያ ድረስ በ ቡንደስሊጋ ውስጥ አን...  ...    9.728
# 20  እነዚህ ጉዳት የ ደረሰባቸው ኢትዮጵያውያ ን በ ሳር ቤት ሞያሌ መንገድ ከ...  ...    8.320
# 21  ኢትዮጵያዊያ ኑ የ ደቡብ አፍሪካ ፕሮፌሰር ጣልቃ እንዲ ገባ እንዲ ገቡ ተማጸኑ  ...    5.760
# 22  እነዚህ ኢትዮጵያውያ ን ኬንያ ዊያን ና ናይጄሪያ ዎች በ ቱርክ ድንበር ላ...  ...   12.160
# 23          የ ዩኒቨርስቲ ተማሪዎች ትናንት ያወጡ ት መግለጫ የ ሚከተለው ነው  ...    4.864
# 24  በ በየነ ጴጥሮስ የሚ መራው የ ተቃዋሚዎች ቅንጅት ብዛት ያ ላቸው ብሄራዊ...  ...    7.296
# 25  በ ተጨማሪ ም ሰማኒያ አንድ ከ መቶ የሚ ሆነው የ ኢትዮጵያ ህዝብ የ ተሟ...  ...    8.064
# 26                  የ ሉ ሲ ቅሪት አሜሪካ ተወስዶ እንደሚ ጐበኝ ተገለጸ  ...    4.864
# 27               ስለዚህ ም እንደ ገና የ ረሀቡ ን ቁልቁለት ይ ያያ ዘዋል  ...    6.016
# 28         ይሁን እንጂ ኢዴፓ ሰላማዊ ትግሉ ሊ ጠናከር እንደሚ ገባ ያ ም ናል  ...    5.504
# 29  በዚህ ጉዳይ ላይ የ ፕሮጀክቱ አስተባባሪ የሆኑት አቶ ኤልያስ እንዳለ ን ...  ...    8.320
# 30                           ህሊናቸው ንም በመ ን ካቴ ደስተኛ ነኝ  ...    3.328
# 31                የ ኦነግ ጦር አዛዥ በ ስቅላት እንዲ ቀጡ ተፈረደ ባቸው  ...    4.480
# 32  የ ኢትዮጵያ ነጻ ፕሬስ ጋዜጠኞች ማህበር በ ቅርቡ በ ኢትዮጵያ ውስጥ ስም...  ...    8.832
# 33  ኦህዴዱ የ ኦሮሚያ ምክትል ፕሬዚዳንት ኮብል ለ ው ዋሽንግተን ውስጥ ከ ኦ...  ...    7.680
# 34      ኢትዮጵያ በምት ገኝበት ስብሰባ አን ካፈል ም አሉ የ ሶማሊያ ፕሬዚዳንት  ...    5.504
# 35  ስድስት የ አስቸኳይ ጊዜ ፕሮጀክቶች እንዲ ነደፉ ም የ አንድ ነጥብ አምስ...  ...    6.400
# 36                  የ ፕሬዝዳንት ግርማ ልጅ አባቱ ን ተክቶ ሊ ሰራ ነው  ...    3.712
# 37                     ፕሮፖጋንዳ ው በ ሻእቢያ ፋሽ ን ይባላል ዛሬ ም  ...    3.328
# 38   ሀያ አራት ክትትል ደህንነቶች እርስ በርስ ተገማግመው ከስራ ገበታ ቸው ተነሱ  ...    6.272
# 39                              ተ ገንጥላ ም ከ እኛው ጋር ና ት  ...    2.944
# 40  ስለ ስደተኞች መወያየት ግን ነገሩን ያሰፋው ና ከ አጉል አምባጓሮ ውስጥ ...  ...    5.504
# 41         እንደ ገና እንዲያ ንሰራሩ የ ህይወት እስትንፋ ስ ነው የዘራ ባቸው  ...    5.504
# 42  ገና ለ ጀሮ ያል በቁ የ ጓዳ ምስጢሮች ካ ሏቸው ይንገሩ ን ለ ነገሩ እና...  ...    5.760
# 43  አሁን ም የ ኢትዮጵያ ህዝብ ዳር እስከ ዳር ያለ ገደብ ገንዘብ እንዲ ያዋ...  ...    5.120
# 44                የቤተ ክርስቲያኒቱ ን አመራር ና አማን ያኑን እን ጠይቅ  ...    3.968
# 45  በ ሻእቢያ በኩል እንኳ ዛሬ መንግስት ሁነ ን ትናንት ም ሰላሳ አመት ተዋ...  ...    6.784
# 46  ህብረቱ ም ጠንካራ ና ዲሞክራሲያዊ ት ኢትዮጵያ እንደምት መሰረት እምነቱ ...  ...    5.760
# 47  ከ ሶስት ሺ በላይ ኤርትራውያን ከ ሀገር ተባረሩ በውጭ የሚኖሩ ትም ተቃው...  ...    5.504
# 48                  በዚህ ደግሞ አትራፊ ዎች እንጂ ተጐጂዎች አይደለ ንም  ...    3.968
# 49  ይህ ሁኔታ በ ኮንጐ ዴሞክራቲክ ሪፐብሊክ የተፈጠረ ውን ችግር ሊ ያወሳስበ...  ...    7.808
#
# [50 rows x 5 columns]
